# %% [markdown]
# # UT-ECE Extended Final Assignment Workbook
#
# This workbook is aligned with `latex/assignment_extended.tex` and structured for Q1-Q14 plus the integrated capstone.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

HERE = Path.cwd().resolve()
CODE_ROOT = None
for candidate in [HERE, HERE.parent, HERE.parent.parent]:
    if (candidate / 'scripts' / 'full_solution_pipeline.py').exists():
        CODE_ROOT = candidate
        break
    if (candidate / 'code' / 'scripts' / 'full_solution_pipeline.py').exists():
        CODE_ROOT = candidate / 'code'
        break

if CODE_ROOT is None:
    raise FileNotFoundError('Run from repo root or code/notebooks so project root can be resolved.')

sys.path.insert(0, str(CODE_ROOT / 'scripts'))

from full_solution_pipeline import load_dataset

DATA_PATH = CODE_ROOT / 'data' / 'GlobalTechTalent_50k.csv'
df = load_dataset(DATA_PATH)
print('Shape:', df.shape)
print('Columns:', len(df.columns))

# %% [markdown]
# ## Q1 - Data Science Lifecycle and Problem Framing
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q1 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q2 - Python Data Operations and EDA
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q2 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q3 - Scientific Studies and Statistical Inference
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q3 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q4 - Visualization Design and Storytelling
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q4 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q5 - SQL Advanced Querying
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q5 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q6 - Leakage and Big-Data Architecture
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q6 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q7 - Linear/Logistic Models and Elastic Net
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q7 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q8 - Optimization: SGD, Momentum, Adam
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q8 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q9 - SVM/KNN/Trees/Boosting Comparison
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q9 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q10 - Dimensionality Reduction
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q10 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q11 - Clustering: KMeans and DBSCAN
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q11 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q12 - Neural Networks and Sequence Modeling
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q12 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q13 - Language Models and LLM Agents
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q13 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Q14 - Ethics, Fairness, and Governance
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Q14 here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Capstone - Integrated End-to-End Delivery
#
# ### Instructions
# - Implement the requested analysis for this section.
# - Document assumptions and limitations.
# - Add plots/tables where relevant.
#
# ### Written Response
# Fill in your final narrative answer for Capstone here.

# %%
# TODO: Implement code for this section

# %% [markdown]
# ## Final Checklist
#
# - [ ] Reproducibility (seed, versions, deterministic splits)
# - [ ] Leakage audit documented
# - [ ] Metrics + confidence intervals where relevant
# - [ ] Explainability outputs included
# - [ ] Fairness analysis included
# - [ ] Executive summary completed
